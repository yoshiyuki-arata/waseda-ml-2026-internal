# %% [markdown]
# # Sample Colab Demo Notebook
#
# ここでは、
# This notebook is a simple example for GitHub + Google Colab integration.
#
# Author: Your Name
# Date: 2026

# %%
# Check Python version
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
# Simple numerical example
import numpy as np

x = np.random.randn(1000)
print("Mean:", np.mean(x))
print("Std:", np.std(x))

# %%
# Simple visualization
import matplotlib.pyplot as plt

plt.hist(x, bins=30)
plt.title("Histogram Example")
plt.show()

# %% [markdown]
# ## Colab-specific example
#
# If running on Colab, you can install packages like this:
#
# ```python
# !pip install pandas
# ```
